# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/drive/MyDrive/FMCG-Products.csv")
df.head(100)
# Out:
#     Row ID Order Priority  Discount offered  Unit Price  Freight Expenses  \
# 0    20847           High            0.0100        2.84              0.93
# 1    23086           High            0.0300        6.68              6.15
# 2    23087           High            0.0100        5.68              3.60
# 3    23088  Not Specified            0.0001      205.99              2.50
# 4    23597           High            0.0900       55.48             14.30
# ..     ...            ...               ...         ...               ...
# 95   25265            Low            0.0200      125.99              3.00
# 96   24682         Medium            0.0100       15.98              4.00
# 97   25661           High            0.0600      499.99             24.49
# 98   26106           High            0.1000       18.65              3.77
# 99   26107           High            0.0001        2.88              1.49
#
#     Customer ID Name of customer Freight Mode                  Segment  \
# ...

# %%
df.isnull().head()
# Out:
#    Row ID  Order Priority  Discount offered  Unit Price  Freight Expenses  \
# 0   False           False             False       False             False
# 1   False           False             False       False             False
# 2   False           False             False       False             False
# 3   False           False             False       False             False
# 4   False           False             False       False             False
#
#    Customer ID  Name of customer  Freight Mode  Segment  Product Type  ...  \
# 0        False             False         False    False         False  ...
# 1        False             False         False    False         False  ...
# 2        False             False         False    False         False  ...
# 3        False             False         False    False         False  ...
# 4        False             False         False    False         False  ...
#
#    Region  Country  ZIP Code  Order Date  Ship Date  Profit  \
# ...

# %%
df.isnull().sum()
# Out:
# Row ID                     0
# Order Priority             0
# Discount offered           0
# Unit Price                 0
# Freight Expenses           0
# Customer ID                0
# Name of customer           0
# Freight Mode               0
# Segment                    0
# Product Type               0
# Product Sub-Category       0
# Product Container          0
# Product Base Margin       31
# State                      0
# City                       0
# Region                     0
# Country                    0
# ZIP Code                2549
# Order Date                 0
# Ship Date                  0
# Profit                     0
# Quantity ordered new       0
# Sales                      0
# Target                  1673
# Order ID                   0
# dtype: int64

# %%
df.dtypes
# Out:
# Row ID                    int64
# Order Priority           object
# Discount offered        float64
# Unit Price              float64
# Freight Expenses        float64
# Customer ID               int64
# Name of customer         object
# Freight Mode             object
# Segment                  object
# Product Type             object
# Product Sub-Category     object
# Product Container        object
# Product Base Margin     float64
# State                    object
# City                     object
# Region                   object
# Country                  object
# ZIP Code                float64
# Order Date               object
# Ship Date                object
# Profit                  float64
# Quantity ordered new      int64
# Sales                   float64
# Target                  float64
# Order ID                  int64
# dtype: object

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'])
df.dtypes
# Out:
# Row ID                           int64
# Order Priority                  object
# Discount offered               float64
# Unit Price                     float64
# Freight Expenses               float64
# Customer ID                      int64
# Name of customer                object
# Freight Mode                    object
# Segment                         object
# Product Type                    object
# Product Sub-Category            object
# Product Container               object
# Product Base Margin            float64
# State                           object
# City                            object
# Region                          object
# Country                         object
# ZIP Code                       float64
# Order Date              datetime64[ns]
# Ship Date               datetime64[ns]
# Profit                         float64
# Quantity ordered new             int64
# Sales                          float64
# Target                         float64
# ...

# %%
df1 = df.dropna()

# %%
df1
# Out:
#       Row ID Order Priority  Discount offered  Unit Price  Freight Expenses  \
# 2      23087           High            0.0100        5.68              3.60
# 3      23088  Not Specified            0.0001      205.99              2.50
# 5      25549            Low            0.0800      120.97             26.30
# 6      24782           High            0.0100       90.24              0.99
# 9      24565       Critical            0.1000       85.99              0.99
# ...      ...            ...               ...         ...               ...
# 1682   26154  Not Specified            0.0300       16.16              7.74
# 1683   26140           High            0.0400        5.98              7.15
# 1686   22719           High            0.0400        5.40              7.78
# 1687   25914           High            0.1000      105.98             13.99
# 1688   24492           High            0.0900        7.78              2.50
#
# ...

# %%
df1.isnull().sum()
# Out:
# Row ID                  0
# Order Priority          0
# Discount offered        0
# Unit Price              0
# Freight Expenses        0
# Customer ID             0
# Name of customer        0
# Freight Mode            0
# Segment                 0
# Product Type            0
# Product Sub-Category    0
# Product Container       0
# Product Base Margin     0
# State                   0
# City                    0
# Region                  0
# Country                 0
# ZIP Code                0
# Order Date              0
# Ship Date               0
# Profit                  0
# Quantity ordered new    0
# Sales                   0
# Target                  0
# Order ID                0
# dtype: int64

# %%
df1.keys()
# Out:
# Index(['Row ID', 'Order Priority', 'Discount offered', 'Unit Price',
#        'Freight Expenses', 'Customer ID', 'Name of customer', 'Freight Mode',
#        'Segment', 'Product Type', 'Product Sub-Category', 'Product Container',
#        'Product Base Margin', 'State', 'City', 'Region', 'Country', 'ZIP Code',
#        'Order Date', 'Ship Date', 'Profit', 'Quantity ordered new', 'Sales',
#        'Target', 'Order ID'],
#       dtype='object')

# %%
print(df1.Segment)
# Out:
# 2       Hotels / Hospitals
# 3       Hotels / Hospitals
# 5       Hotels / Hospitals
# 6         Restaurant Chain
# 9         Restaurant Chain
#                ...
# 1682    Hotels / Hospitals
# 1683    Hotels / Hospitals
# 1686    Hotels / Hospitals
# 1687        Personel Usage
# 1688        Personel Usage
# Name: Segment, Length: 1024, dtype: object

# %%
print(df1['Segment'].value_counts()['Hotels / Hospitals'])
# Out:
# 346

# %%
print(df1['Segment'].value_counts()['Personel Usage'])
# Out:
# 234

# %%
print(df1['Segment'].value_counts()['Restaurant Chain'])
# Out:
# 252

# %%
print(df1['Order Priority'].value_counts()['High'])
# Out:
# 530

# %%
print(df1.describe())
# Out:
#              Row ID  Discount offered   Unit Price  Freight Expenses  \
# count   1024.000000       1024.000000  1024.000000       1024.000000
# mean   21067.479492          0.049032   103.288828         12.179414
# std     5075.901219          0.031305   372.400385         15.885093
# min      257.000000          0.000100     1.260000          0.490000
# 25%    19683.750000          0.020000     8.330000          3.000000
# 50%    21819.000000          0.050000    31.045000          5.810000
# 75%    24238.500000          0.080000    95.990000         13.990000
# max    26392.000000          0.100000  6783.020000         91.050000
#
#        Customer ID  Product Base Margin      ZIP Code        Profit  \
# count  1024.000000          1024.000000   1024.000000   1024.000000
# mean   1984.037109             0.520879  60236.193359    139.300545
# std     951.881056             0.127348  28606.974683   1223.714946
# min       3.000000             0.350000  20151.000000 -16476.838000
# ...

# %%
print(df1[2:5])
# Out:
#    Row ID Order Priority  Discount offered  Unit Price  Freight Expenses  \
# 5   25549            Low              0.08      120.97             26.30
# 6   24782           High              0.01       90.24              0.99
# 9   24565       Critical              0.10       85.99              0.99
#
#    Customer ID Name of customer    Freight Mode             Segment  \
# 5            3            Mynte  Delivery Truck  Hotels / Hospitals
# 6            6         Devpulse     Regular Air    Restaurant Chain
# 9            6         Devpulse     Regular Air    Restaurant Chain
#
#      Product Type  ... Region Country  ZIP Code Order Date  Ship Date  \
# 5    Canned Foods  ...   West     USA   98221.0 2013-07-01 2013-07-08
# 6  Processed Meat  ...   West     USA   95123.0 2011-05-26 2011-05-26
# 9    Canned Foods  ...   West     USA   95123.0 2012-12-29 2012-12-31
#
#       Profit Quantity ordered new    Sales  Target Order ID
# ...

# %%
df1.filter(['City'])
# Out:
#            City
# 2     Anacortes
# 3     Anacortes
# 5     Anacortes
# 6      San Jose
# 9      San Jose
# ...         ...
# 1682   Marietta
# 1683   Marietta
# 1686  Fairfield
# 1687   Cheyenne
# 1688   Cheyenne
#
# [1024 rows x 1 columns]

# %%
print(df1['Profit'].mean())
print(df1['Profit'].median())
print(df1['Profit'].mode())
# Out:
# 139.30054452304685
# 4.47675
# 0    23.616
# dtype: float64

# %%
print(df1['Sales'].mean())
print(df1['Sales'].median())
print(df1['Sales'].mode())
# Out:
# 967.46470703125
# 265.76
# 0      8.74
# 1     22.48
# 2     52.27
# 3     65.69
# 4    324.62
# 5    384.22
# dtype: float64

# %%
print(df1['Discount offered'].mean())
print(df1['Discount offered'].median())
print(df1['Discount offered'].mode())
# Out:
# 0.04903203125000001
# 0.05
# 0    0.03
# dtype: float64

# %%
print(df1['Order Priority'].tolist())
# Out:
# ['High', 'Not Specified', 'Low', 'High', 'Critical', 'High', 'High', 'High', 'High', 'High', 'Low', 'High', 'High', 'High', 'High', 'High', 'Medium', 'Low', 'High', 'Not Specified', 'Critical', 'High', 'High', 'Medium', 'Low', 'Critical', 'Medium', 'High', 'High', 'High', 'High', 'Critical', 'Medium', 'Critical', 'High', 'High', 'Medium', 'Not Specified', 'High', 'Medium', 'High', 'Medium', 'Low', 'High', 'Critical', 'High', 'Medium', 'Low', 'High', 'Low', 'High', 'High', 'High', 'Critical', 'High', 'High', 'Low', 'Low', 'High', 'High', 'Low', 'High', 'High', 'High', 'Medium', 'Medium', 'High', 'High', 'Not Specified', 'Medium', 'Not Specified', 'High', 'Not Specified', 'Not Specified', 'Not Specified', 'High', 'Critical', 'Low', 'Low', 'Low', 'High', 'Medium', 'High', 'High', 'High', 'Low', 'High', 'High', 'High', 'Low', 'High', 'Low', 'High', 'High', 'High', 'High', 'High', 'Not Specified', 'High', 'High', 'High', 'High', 'Medium', 'Low', 'High', 'Low', 'Critical', 'Critical', 'Med
# ...

# %%
print(df1.loc[:,'Product Type'])
# Out:
# 2       Processed Meat
# 3         Canned Foods
# 5         Canned Foods
# 6       Processed Meat
# 9         Canned Foods
#              ...
# 1682    Preserved Food
# 1683    Processed Meat
# 1686    Processed Meat
# 1687    Preserved Food
# 1688    Processed Meat
# Name: Product Type, Length: 1024, dtype: object

# %%
print(df1['Target'].value_counts()<=100)
# Out:
# 1800.0    False
# 200.0     False
# 1000.0    False
# 100.0      True
# 800.0      True
# 1500.0     True
# 160.0      True
# 75.0       True
# 600.0      True
# 250.0      True
# 80.0       True
# 55.0       True
# 85.0       True
# 5000.0     True
# 64.0       True
# 450.0      True
# Name: Target, dtype: bool

# %%
print(df1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1024 entries, 2 to 1688
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                1024 non-null   int64
#  1   Order Priority        1024 non-null   object
#  2   Discount offered      1024 non-null   float64
#  3   Unit Price            1024 non-null   float64
#  4   Freight Expenses      1024 non-null   float64
#  5   Customer ID           1024 non-null   int64
#  6   Name of customer      1024 non-null   object
#  7   Freight Mode          1024 non-null   object
#  8   Segment               1024 non-null   object
#  9   Product Type          1024 non-null   object
#  10  Product Sub-Category  1024 non-null   object
#  11  Product Container     1024 non-null   object
#  12  Product Base Margin   1024 non-null   float64
#  13  State                 1024 non-null   object
#  14  City                  1024 non-null   object
# ...

# %%
print(df1.describe(include='all'))
# Out:
#               Row ID Order Priority  Discount offered   Unit Price  \
# count    1024.000000           1024       1024.000000  1024.000000
# unique           NaN              5               NaN          NaN
# top              NaN           High               NaN          NaN
# freq             NaN            530               NaN          NaN
# first            NaN            NaN               NaN          NaN
# last             NaN            NaN               NaN          NaN
# mean    21067.479492            NaN          0.049032   103.288828
# std      5075.901219            NaN          0.031305   372.400385
# min       257.000000            NaN          0.000100     1.260000
# 25%     19683.750000            NaN          0.020000     8.330000
# 50%     21819.000000            NaN          0.050000    31.045000
# 75%     24238.500000            NaN          0.080000    95.990000
# max     26392.000000            NaN          0.100000  6783.020000
#
# ...

# %%
sns.countplot(x='Order Priority', data=df1)

# %%
print(sns.countplot(x='Freight Mode', data=df1))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
sns.displot(x = 'Product Base Margin',kde=True,bins = 15, data =df1)

# %%
sns.pairplot(df1)

# %%
sns.scatterplot(x='Profit', y ='Sales' ,
data = df1 , hue = 'Region')

# %%
sns.lineplot(x="Profit", y="Sales", data=df1)
plt.show()

# %%
x = np.random.normal(100, 50, 135)
plt.hist(x)
plt.show()

# %%
sns.set_style("whitegrid")
sns.boxplot(x = 'Sales', y = 'Freight Mode', data = df1)

# %%
np.random.seed(0)
sns.set()
uniform_data = np.random.rand(9, 11)
ax = sns.heatmap(uniform_data, vmin=0, vmax=1)
plt.show()

# %%
fmcg = df1.pivot("Profit", "Sales", "Target")
ax = sns.heatmap(fmcg)
plt.title("Heatmap FMCG Data")
plt.show()
